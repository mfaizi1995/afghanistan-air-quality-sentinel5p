# %% [markdown]
# # Satellite-Based Air Quality Insights for Afghan Cities
#
# This project uses open satellite data (e.g., Sentinel-5P) to explore air pollution patterns in major Afghan cities such as Kabul, Herat, and Mazar-e Sharif. The goal is to create clear, reproducible analyses and visualizations that can support environmental awareness and advocacy.

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Python version:", sys.version)
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Python version: 3.11.14 (main, Oct 21 2025, 18:27:30) [Clang 20.1.8 ]
# Pandas version: 2.3.3
# NumPy version: 2.3.5

# %%
import ee

ee.Initialize()

# simple test: get information about a random Sentinel-5P image
collection = ee.ImageCollection("COPERNICUS/S5P/OFFL/L3_NO2").first()
info = collection.getInfo()

print("Earth Engine Initialized!")
print("Sample Image ID:", info['id'])
# Out:
# Earth Engine Initialized!
# Sample Image ID: COPERNICUS/S5P/OFFL/L3_NO2/20180628T102407_20180704T120838

# %%
import geemap
Map = geemap.Map(center=[34.53, 69.17], zoom=9)  # center on Kabul
Map
# Out:
# Map(center=[34.53, 69.17], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright'…
